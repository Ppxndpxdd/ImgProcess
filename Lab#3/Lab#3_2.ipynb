# %%
import numpy as np
import cv2
from keras.models import Model 
from matplotlib import pyplot as plt
from tensorflow.keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import img_to_array
from numpy import expand_dims
from scipy import signal
from IPython.display import Image, display

# %%
model = VGG16()

# %%
kernels, biases = model.layers[1].get_weights()

# %%
img = cv2.imread("C:/Users/PP's Notebook/Desktop/imgProcess/Lab#3/test.jpg")

# %%
if img is not None:
    # Define the new width and height
    new_width = 224  # Replace with your desired width
    new_height = 224  # Replace with your desired height

    # Resize the image
    resized_image = cv2.resize(img, (new_width, new_height))

    # Convert the BGR image to RGB for proper display
    resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

    # Display the resized image using matplotlib
    plt.imshow(resized_image_rgb)
    plt.axis('off')  # Turn off axis labels and ticks
    plt.show()
else:
    print('Failed to read the image.')

# %%
if resized_image_rgb is not None:
    # Convert the image to float32 data type for accurate calculations
    resized_image_rgb = resized_image_rgb.astype(np.float32)
else:
    print('Failed to read the image.')

# %%
mean_b = 123.68
mean_g = 116.779
mean_r = 103.939

# %%
resized_image_rgb[:, :, 0] -= mean_b
resized_image_rgb[:, :, 1] -= mean_g
resized_image_rgb[:, :, 2] -= mean_r

# %%
plt.imshow(cv2.cvtColor(resized_image_rgb, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
